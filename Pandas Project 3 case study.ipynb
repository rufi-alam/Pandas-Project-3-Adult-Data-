# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('adultdata.csv')

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#             maritalstatus         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %% [markdown]
# # 1.Display Top 10 Rows of The Dataset

# %%
data.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#         maritalstatus         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %% [markdown]
# # 2.Check Last 10 Rows of The Dataset

# %%
data.tail(10)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48832   32       Private   34066          10th                6
# 48833   43       Private   84661     Assoc-voc               11
# 48834   32       Private  116138       Masters               14
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#             maritalstatus         occupation   relationship  \
# 48832  Married-civ-spouse  Handlers-cleaners        Husband
# 48833  Married-civ-spouse              Sales        Husband
# 48834       Never-married       Tech-support  Not-in-family
# ...

# %% [markdown]
# # 3.Find Shape of Our Dataset(Number of Rows And Number of Columns)

# %%
data.shape
# Out:
# (48842, 15)

# %%
print('Number of rows',data.shape[0])
# Out:
# Number of rows 48842

# %%
print('Number of columns',data.shape[1])
# Out:
# Number of columns 15

# %% [markdown]
# # 4.Getting Information About Our Dataset Like Total Number Rows,Total Number Columns,Datatypes of Each Column and Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   maritalstatus    48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capitalgain      48842 non-null  int64
#  11  capitalloss      48842 non-null  int64
#  12  hoursperweek     48842 non-null  int64
#  13  nativecountry    48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# # 5.Fetch Random Samples From the Dataset(50%)

# %%
data1=data.sample(frac=0.50,random_state=110)

# %%
data1
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 5200    42         State-gov  200294     Bachelors               13
# 24936   33           Private  172304          10th                6
# 46035   48           Private  317360  Some-college               10
# 35912   34           Private  150324     Bachelors               13
# 29903   25           Private  104097     Bachelors               13
# ...    ...               ...     ...           ...              ...
# 29585   60           Private  145995     Bachelors               13
# 21262   41           Private  252058     Bachelors               13
# 9490    39           Private  247515       HS-grad                9
# 48343   26                 ?  375313  Some-college               10
# 958     41  Self-emp-not-inc  134724     Assoc-voc               11
#
#             maritalstatus         occupation   relationship  \
# 5200             Divorced     Prof-specialty      Unmarried
# ...

# %% [markdown]
# # 6.Fetch Random Sample From The Dataset(70%)

# %%
data2=data.sample(frac=0.70,random_state=210)

# %%
data2
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 10909   36    Private  144752       HS-grad                9
# 37588   38  State-gov  203628     Bachelors               13
# 42215   47    Private  503454          12th                8
# 7625    18    Private  170094       HS-grad                9
# 20991   26    Private  210812  Some-college               10
# ...    ...        ...     ...           ...              ...
# 37568   17    Private  121425          11th                7
# 5346    30    Private   53285     Assoc-voc               11
# 27979   17    Private  150262          11th                7
# 33321   46    Private  173243       HS-grad                9
# 21106   47    Private  168232  Some-college               10
#
#             maritalstatus         occupation    relationship  \
# 10909  Married-civ-spouse       Craft-repair         Husband
# 37588  Married-civ-spouse     Prof-specialty         Husband
# ...

# %% [markdown]
# # 6.Check Null Values Column Wise In The Dataset

# %%
data.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# maritalstatus      0
# occupation         0
# relationship       0
# race               0
# gender             0
# capitalgain        0
# capitalloss        0
# hoursperweek       0
# nativecountry      0
# income             0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot: >

# %% [markdown]
# # 7.Check Null Values Row Wise In The Dataset

# %%
data.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 48837    0
# 48838    0
# 48839    0
# 48840    0
# 48841    0
# Length: 48842, dtype: int64

# %% [markdown]
# # 8.Perform Data Cleaning[ Replace '?' with NaN ]

# %%
data.tail(20)
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 48822   41                 ?  202822       HS-grad                9
# 48823   72                 ?  129912       HS-grad                9
# 48824   45         Local-gov  119199    Assoc-acdm               12
# 48825   31           Private  199655       Masters               14
# 48826   39         Local-gov  111499    Assoc-acdm               12
# 48827   37           Private  198216    Assoc-acdm               12
# 48828   43           Private  260761       HS-grad                9
# 48829   65  Self-emp-not-inc   99359   Prof-school               15
# 48830   43         State-gov  255835  Some-college               10
# 48831   43  Self-emp-not-inc   27242  Some-college               10
# 48832   32           Private   34066          10th                6
# 48833   43           Private   84661     Assoc-voc               11
# 48834   32           Private  116138       Masters               14
# ...

# %%
data.isin(['?']).sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# maritalstatus         0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capitalgain           0
# capitalloss           0
# hoursperweek          0
# nativecountry       857
# income                0
# dtype: int64

# %%
import numpy as np

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'maritalstatus', 'occupation', 'relationship', 'race', 'gender',
#        'capitalgain', 'capitalloss', 'hoursperweek', 'nativecountry',
#        'income'],
#       dtype='object')

# %%
data['workclass']=data['workclass'].replace('?',np.nan)

# %%
data['occupation']=data['occupation'].replace('?',np.nan)

# %%
data['nativecountry']=data['nativecountry'].replace('?',np.nan)

# %%
data.isin(['?']).sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# maritalstatus      0
# occupation         0
# relationship       0
# race               0
# gender             0
# capitalgain        0
# capitalloss        0
# hoursperweek       0
# nativecountry      0
# income             0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# maritalstatus         0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capitalgain           0
# capitalloss           0
# hoursperweek          0
# nativecountry       857
# income                0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot: >

# %% [markdown]
# # 9.Drop All The Missing Values

# %%
per_missing=data.isnull().sum()*100/len(data)

# %%
per_missing
# Out:
# age                0.000000
# workclass          5.730724
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# maritalstatus      0.000000
# occupation         5.751198
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capitalgain        0.000000
# capitalloss        0.000000
# hoursperweek       0.000000
# nativecountry      1.754637
# income             0.000000
# dtype: float64

# %%
data.dropna(how='any',inplace=True)

# %%
data.shape
# Out:
# (45222, 15)

# %%
48842-45222
# Out:
# 3620

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot: >

# %% [markdown]
# # 10.Check For Duplicate Data and Drop Them

# %%
duplicate=data.duplicated().any()

# %%
print('is there any duplicated value',duplicate)
# Out:
# is there any duplicated value True

# %%
data=data.drop_duplicates()

# %%
data.shape
# Out:
# (45175, 15)

# %%
45222-45175
# Out:
# 47

# %% [markdown]
# # 12.Get Overall Statistics About The Dataframe

# %%
data.describe(include='all')
# Out:
#                  age workclass        fnlwgt education  educational-num  \
# count   45175.000000     45175  4.517500e+04     45175     45175.000000
# unique           NaN         7           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     33262           NaN     14770              NaN
# mean       38.556170       NaN  1.897388e+05       NaN        10.119314
# std        13.215349       NaN  1.056524e+05       NaN         2.551740
# min        17.000000       NaN  1.349200e+04       NaN         1.000000
# 25%        28.000000       NaN  1.173925e+05       NaN         9.000000
# 50%        37.000000       NaN  1.783120e+05       NaN        10.000000
# 75%        47.000000       NaN  2.379030e+05       NaN        13.000000
# max        90.000000       NaN  1.490400e+06       NaN        16.000000
#
#              maritalstatus    occupation relationship   race gender  \
# ...

# %% [markdown]
# # 13.Drop The columns education-num capital-gain and capital-loss

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'maritalstatus', 'occupation', 'relationship', 'race', 'gender',
#        'capitalgain', 'capitalloss', 'hoursperweek', 'nativecountry',
#        'income'],
#       dtype='object')

# %%
data=data.drop(['educational-num','capitalgain','capitalloss'],axis=1)

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'gender', 'hoursperweek',
#        'nativecountry', 'income'],
#       dtype='object')

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# # 14.What is the distribution of age columns

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'gender', 'hoursperweek',
#        'nativecountry', 'income'],
#       dtype='object')

# %%
data['age'].describe()
# Out:
# count    45175.000000
# mean        38.556170
# std         13.215349
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         47.000000
# max         90.000000
# Name: age, dtype: float64

# %%
data['age'].hist()
# Out:
# <AxesSubplot: >

# %% [markdown]
# # 15.What is the distribution of fnlwgt columns

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'gender', 'hoursperweek',
#        'nativecountry', 'income'],
#       dtype='object')

# %%
data['fnlwgt'].describe()
# Out:
# count    4.517500e+04
# mean     1.897388e+05
# std      1.056524e+05
# min      1.349200e+04
# 25%      1.173925e+05
# 50%      1.783120e+05
# 75%      2.379030e+05
# max      1.490400e+06
# Name: fnlwgt, dtype: float64

# %%
data['fnlwgt'].hist()
# Out:
# <AxesSubplot: >

# %% [markdown]
# # 16.Find Total Number of persons having age between 17 to 48 (inclusive) using between methods

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'gender', 'hoursperweek',
#        'nativecountry', 'income'],
#       dtype='object')

# %% [markdown]
# # Not using between method

# %%
sum((data['age']>=17) & (data['age']<=48))
# Out:
# 34858

# %% [markdown]
# # Using between method

# %%
sum(data['age'].between(17,48))
# Out:
# 34858

# %% [markdown]
# # 17.What is the distribution of workclass columns

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'gender', 'hoursperweek',
#        'nativecountry', 'income'],
#       dtype='object')

# %%
data['workclass'].describe()
# Out:
# count       45175
# unique          7
# top       Private
# freq        33262
# Name: workclass, dtype: object

# %%
plt.figure(figsize=(7,7))
data['workclass'].hist()
# Out:
# <AxesSubplot: >

# %% [markdown]
# # 18.How many Persons having bachelors or master degree

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'gender', 'hoursperweek',
#        'nativecountry', 'income'],
#       dtype='object')

# %%
data1=data['education']=='Bachelors'
data2=data['education']=='Masters'

# %%
data[data1|data2]
# Out:
#        age    workclass  fnlwgt  education       maritalstatus  \
# 11      36  Federal-gov  212465  Bachelors  Married-civ-spouse
# 15      43      Private  346189    Masters  Married-civ-spouse
# 20      34      Private  107914  Bachelors  Married-civ-spouse
# 23      25      Private  220931  Bachelors       Never-married
# 24      25      Private  205947  Bachelors  Married-civ-spouse
# ...    ...          ...     ...        ...                 ...
# 48817   34      Private  160216  Bachelors       Never-married
# 48819   38      Private  139180  Bachelors            Divorced
# 48825   31      Private  199655    Masters            Divorced
# 48834   32      Private  116138    Masters       Never-married
# 48835   53      Private  321865    Masters  Married-civ-spouse
#
#             occupation   relationship                race  gender  \
# 11        Adm-clerical        Husband               White    Male
# 15     Exec-managerial        Husband               White    Male
# ...

# %%
len(data[data1|data2])
# Out:
# 10072

# %% [markdown]
# # Bivariate Analysis

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'gender', 'hoursperweek',
#        'nativecountry', 'income'],
#       dtype='object')

# %%
sns.boxplot(x='income',y='age',data=data)
# Out:
# <AxesSubplot: xlabel='income', ylabel='age'>

# %% [markdown]
# # 19.Replace Salary Values ['<=50K','>50k'] With 0 and 1

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'gender', 'hoursperweek',
#        'nativecountry', 'income'],
#       dtype='object')

# %%
data['income'].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
data['income'].value_counts()
# Out:
# <=50K    33973
# >50K     11202
# Name: income, dtype: int64

# %%
data.replace(to_replace=['<=50K', '>50K'],value=[0,1],inplace=True)

# %%
data.head(20)
# Out:
#     age         workclass  fnlwgt     education       maritalstatus  \
# 0    25           Private  226802          11th       Never-married
# 1    38           Private   89814       HS-grad  Married-civ-spouse
# 2    28         Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3    44           Private  160323  Some-college  Married-civ-spouse
# 5    34           Private  198693          10th       Never-married
# 7    63  Self-emp-not-inc  104626   Prof-school  Married-civ-spouse
# 8    24           Private  369667  Some-college       Never-married
# 9    55           Private  104996       7th-8th  Married-civ-spouse
# 10   65           Private  184454       HS-grad  Married-civ-spouse
# 11   36       Federal-gov  212465     Bachelors  Married-civ-spouse
# 12   26           Private   82091       HS-grad       Never-married
# 14   48           Private  279724       HS-grad  Married-civ-spouse
# 15   43           Private  346189       Masters  Married-civ-spouse
# ...

# %% [markdown]
# # 20..Replace Salary Values ['0','1'] With 10000 and 13000

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'gender', 'hoursperweek',
#        'nativecountry', 'income'],
#       dtype='object')

# %%
data['income'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data['income'].value_counts()
# Out:
# 0    33973
# 1    11202
# Name: income, dtype: int64

# %%
data.replace(to_replace=[0, 1],value=[10000,13000],inplace=True)

# %%
data.head(20)
# Out:
#     age         workclass  fnlwgt     education       maritalstatus  \
# 0    25           Private  226802          11th       Never-married
# 1    38           Private   89814       HS-grad  Married-civ-spouse
# 2    28         Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3    44           Private  160323  Some-college  Married-civ-spouse
# 5    34           Private  198693          10th       Never-married
# 7    63  Self-emp-not-inc  104626   Prof-school  Married-civ-spouse
# 8    24           Private  369667  Some-college       Never-married
# 9    55           Private  104996       7th-8th  Married-civ-spouse
# 10   65           Private  184454       HS-grad  Married-civ-spouse
# 11   36       Federal-gov  212465     Bachelors  Married-civ-spouse
# 12   26           Private   82091       HS-grad       Never-married
# 14   48           Private  279724       HS-grad  Married-civ-spouse
# 15   43           Private  346189       Masters  Married-civ-spouse
# ...

# %% [markdown]
# # 21.Which workclass getting the highest income

# %%
data.groupby('workclass')['income'].mean()
# Out:
# workclass
# Federal-gov         11171.408250
# Local-gov           10885.483871
# Private             10653.448380
# Self-emp-inc        11663.221884
# Self-emp-not-inc    10837.154150
# State-gov           10801.644399
# Without-pay         10285.714286
# Name: income, dtype: float64

# %% [markdown]
# # 22.How Has Better chance to get salary >50k male or female

# %%
data.groupby('gender')['income'].mean()
# Out:
# gender
# Female    10341.076294
# Male      10937.825873
# Name: income, dtype: float64

# %% [markdown]
# # 23.Convert workclass columns datatype to category datatype

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45175 entries, 0 to 48841
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            45175 non-null  int64
#  1   workclass      45175 non-null  object
#  2   fnlwgt         45175 non-null  int64
#  3   education      45175 non-null  object
#  4   maritalstatus  45175 non-null  object
#  5   occupation     45175 non-null  object
#  6   relationship   45175 non-null  object
#  7   race           45175 non-null  object
#  8   gender         45175 non-null  object
#  9   hoursperweek   45175 non-null  int64
#  10  nativecountry  45175 non-null  object
#  11  income         45175 non-null  int64
# dtypes: int64(4), object(8)
# memory usage: 4.5+ MB

# %%
data['workclass']=data['workclass'].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45175 entries, 0 to 48841
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            45175 non-null  int64
#  1   workclass      45175 non-null  category
#  2   fnlwgt         45175 non-null  int64
#  3   education      45175 non-null  object
#  4   maritalstatus  45175 non-null  object
#  5   occupation     45175 non-null  object
#  6   relationship   45175 non-null  object
#  7   race           45175 non-null  object
#  8   gender         45175 non-null  object
#  9   hoursperweek   45175 non-null  int64
#  10  nativecountry  45175 non-null  object
#  11  income         45175 non-null  int64
# dtypes: category(1), int64(4), object(7)
# memory usage: 4.2+ MB
